# %% [markdown]
# # Mais personalizações possíveis

# %% [markdown]
# ## Gráfico de barras para apresentação
#
# Considere que você tem as quantidades de produtos vendidos em uma loja. Faça um gráfico de barras horizontais.

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

# %%
barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, fontsize=10, padding=2)

plt.box(False) # removendo a caixa do gráfico

plt.xticks([]) # Tirando os números do eixo x

plt.tick_params(axis='y', length=0) #Tirando o pequeno traço antes da barra

plt.title('Quantidade de produtos vendidos')

plt.show()

# %%
#Storytelling, quero destacar o produto B
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos, quantidades)

rotulos = [valor if valor == max(quantidades) else '' for valor in quantidades]

plt.bar_label(barras, labels=rotulos, fontsize=10, padding=2)

plt.box(False) # removendo a caixa do gráfico

plt.xticks([]) # Tirando os números do eixo x

plt.tick_params(axis='y', length=0) #Tirando o pequeno traço antes da barra

for i, barrra in enumerate(barras):
    if i != quantidades.index(max(quantidades)): #Se não for o íncide do produto com valor máximo
        barras[i].set_color(cores[4])
        barras[i].set_alpha(0.3) # opacidade 30%

plt.title('Quantidade de produtos vendidos')

plt.show()

# %%
dados_ordenados = sorted(zip(quantidades, produtos))
quantidades_ordenadas = [dado[0] for dado in dados_ordenados]
produtos_ordenados = [dado[1] for dado in dados_ordenados]
print(produtos_ordenados)
# Out:
# ['Produto C', 'Produto A', 'Produto D', 'Produto E', 'Produto B']

# %%
#Storytelling, quero destacar o produto B


cores = plt.get_cmap('Set3').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

rotulos = [valor if valor == max(quantidades_ordenadas) else '' for valor in quantidades_ordenadas]

plt.bar_label(barras, labels=rotulos, fontsize=10, padding=2)

plt.box(False) # removendo a caixa do gráfico

plt.xticks([]) # Tirando os números do eixo x

plt.tick_params(axis='y', length=0) #Tirando o pequeno traço antes da barra

for i, barrra in enumerate(barras):
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)): #Se não for o íncide do produto com valor máximo
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.3) # opacidade 30%

plt.title('Quantidade de produtos vendidos')

plt.gca().invert_yaxis() #Invertendo a ordem dos produtos

plt.show()

# %%
#Storytelling, quero destacar o produto B


cores = plt.get_cmap('Set3').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.bar(produtos_ordenados, quantidades_ordenadas)

rotulos = [valor if valor == max(quantidades_ordenadas) else '' for valor in quantidades_ordenadas]

plt.bar_label(barras, labels=rotulos, fontsize=10, padding=2)

plt.box(False) # removendo a caixa do gráfico

plt.yticks([]) # Tirando os números do eixo x

plt.tick_params(axis='x', length=0) #Tirando o pequeno traço antes da barra

for i, barrra in enumerate(barras):
    if i != quantidades_ordenadas.index(max(quantidades_ordenadas)): #Se não for o íncide do produto com valor máximo
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.3) # opacidade 30%

plt.title('Quantidade de produtos vendidos')

plt.gca().invert_xaxis() #Invertendo a ordem dos produtos

plt.show()
